# %%
import pandas as pd
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\USER\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\USER\AppData\Local\Temp\ipykernel_6428\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
# ...

# %%
df1=pd.read_csv('C:\\Users\\USER\\Downloads\\Airbnb+Data\\Airbnb Data\\Listings.csv',encoding="latin1")
autostrip=True
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6428\1255442567.py:1: DtypeWarning: Columns (5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('C:\\Users\\USER\\Downloads\\Airbnb+Data\\Airbnb Data\\Listings.csv',encoding="latin1")

# %%
df2=pd.read_csv("C:\\Users\\USER\\Downloads\\Airbnb+Data\\Airbnb Data\\Reviews.csv")
autostrip=True

# %%
df1_copy=df1.copy()

# %%
df2_copy=df2.copy()

# %%
merged_data=pd.merge(df1,df2,on="listing_id")

# %%
merged_data
# Out:
#          listing_id                                               name  \
# 0            281420     Beautiful Flat in le Village Montmartre, Paris
# 1            281420     Beautiful Flat in le Village Montmartre, Paris
# 2           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# 3           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# 4           3705183                    39 mÃÂ² Paris (Sacre CÃ
# âur)
# ...             ...                                                ...
# 5373138    38683356            Nice and cosy mini-appartement in Paris
# 5373139    38683356            Nice and cosy mini-appartement in Paris
# 5373140    39659000  Charming apartment near Rue Saint Maur / Oberk...
# 5373141    40219504        Cosy apartment with view on Canal St Martin
# 5373142    40219504        Cosy apartment with view on Canal St Martin
#
#           host_id  host_since                 host_location  \
# ...

# %%
missing_value_percentages=merged_data.isna().mean()*100
print("Percentage of Missing Values per Column:")
print(missing_value_percentages)
# Out:
# Percentage of Missing Values per Column:
# listing_id                      0.000000
# name                            0.006197
# host_id                         0.000000
# host_since                      0.073309
# host_location                   0.147214
# host_response_time             27.463125
# host_response_rate             27.463125
# host_acceptance_rate           13.929222
# host_is_superhost               0.073309
# host_total_listings_count       0.073309
# host_has_profile_pic            0.073309
# host_identity_verified          0.073309
# neighbourhood                   0.000000
# district                       84.222884
# city                            0.000000
# latitude                        0.000000
# longitude                       0.000000
# property_type                   0.000000
# room_type                       0.000000
# accommodates                    0.000000
# bedrooms                       10.076281
# amenities                       0.000000
# ...

# %%
district_drop=merged_data.drop("district",axis=1)
merged_data=district_drop

# %%
#Drop null values in column
merged_data.dropna(subset=["host_response_rate"],inplace=True)

# %%
#Drop null values in column
merged_data.dropna(subset=["host_acceptance_rate"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["host_response_time"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["bedrooms"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_rating"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_accuracy"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_cleanliness"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_checkin"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_communication"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_location"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["review_scores_value"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["name"],inplace=True)

# %%
#drop null values in column
merged_data.dropna(subset=["host_since"],inplace=True)

# %%
#Rename column 
new_column={"name":"description"}
merged_data=merged_data.rename(columns=new_column)
merged_data.head()
# Out:
#         listing_id                                        description  \
# 279903    39849253                  Warm and Cosy Flat for 2 in Paris
# 279904    39849253                  Warm and Cosy Flat for 2 in Paris
# 279905    39849253                  Warm and Cosy Flat for 2 in Paris
# 279906    39849253                  Warm and Cosy Flat for 2 in Paris
# 279907    40436816  Bright apartment in PIGALLE - Professional Cle...
#
#           host_id  host_since host_location host_response_time  \
# 279903  305389411  2019-10-30            GB     within an hour
# 279904  305389411  2019-10-30            GB     within an hour
# 279905  305389411  2019-10-30            GB     within an hour
# 279906  305389411  2019-10-30            GB     within an hour
# 279907  312774780  2019-11-28            IE     within an hour
#
#         host_response_rate  host_acceptance_rate host_is_superhost  \
# 279903                 1.0                   1.0                 f
# ...

# %%
merged_data["description"]
# Out:
# 279903                     Warm and Cosy Flat for 2 in Paris
# 279904                     Warm and Cosy Flat for 2 in Paris
# 279905                     Warm and Cosy Flat for 2 in Paris
# 279906                     Warm and Cosy Flat for 2 in Paris
# 279907     Bright apartment in PIGALLE - Professional Cle...
#                                  ...
# 5234959                   Appartement piscine place d'Italie
# 5234960            Cozy Montmartre flat near Le Moulin Rouge
# 5234961    Moderne-ancien- jungle urbaine - proche Montma...
# 5234962    Moderne-ancien- jungle urbaine - proche Montma...
# 5234963    Appartement tranquille au cÃ
# âur du 5ÃÂ¨me ...
# Name: description, Length: 3388769, dtype: object

# %%
char_replace=merged_data[~merged_data["description"].str.contains("Ã")]
merged_data=char_replace

# %%
merged_data["host_location"].unique()
# Out:
# array(['GB', 'IE', 'New York, New York, United States', ...,
#        'ItaguaÃ\x83Â\xad, Rio de Janeiro, Brazil',
#        'BrasÃ\x83Â\xadlia de Minas, State of Minas Gerais, Brazil',
#        'istanbul/ Turkey'], dtype=object)

# %%
host_location_drop=merged_data.drop("host_location",axis=1)
merged_data=host_location_drop

# %%
missing_value_percentages=merged_data.isna().mean()*100
print("Percentage of Missing Values per Column:")
print(missing_value_percentages)
# Out:
# Percentage of Missing Values per Column:
# listing_id                     0.0
# description                    0.0
# host_id                        0.0
# host_since                     0.0
# host_response_time             0.0
# host_response_rate             0.0
# host_acceptance_rate           0.0
# host_is_superhost              0.0
# host_total_listings_count      0.0
# host_has_profile_pic           0.0
# host_identity_verified         0.0
# neighbourhood                  0.0
# city                           0.0
# latitude                       0.0
# longitude                      0.0
# property_type                  0.0
# room_type                      0.0
# accommodates                   0.0
# bedrooms                       0.0
# amenities                      0.0
# price                          0.0
# minimum_nights                 0.0
# maximum_nights                 0.0
# review_scores_rating           0.0
# review_scores_accuracy         0.0
# ...

# %%
merged_data
# Out:
#          listing_id                                        description  \
# 279903     39849253                  Warm and Cosy Flat for 2 in Paris
# 279904     39849253                  Warm and Cosy Flat for 2 in Paris
# 279905     39849253                  Warm and Cosy Flat for 2 in Paris
# 279906     39849253                  Warm and Cosy Flat for 2 in Paris
# 279907     40436816  Bright apartment in PIGALLE - Professional Cle...
# ...             ...                                                ...
# 5234958    44273734          Charming duplex near JARDIN DU LUXEMBOURG
# 5234959    44339814                 Appartement piscine place d'Italie
# 5234960    45200617          Cozy Montmartre flat near Le Moulin Rouge
# 5234961    46673032  Moderne-ancien- jungle urbaine - proche Montma...
# 5234962    46673032  Moderne-ancien- jungle urbaine - proche Montma...
#
#            host_id  host_since  host_response_time  host_response_rate  \
# ...

# %%
merged_data.to_csv('Python_Project.csv', index=False)

# %%
merged_data['price']
# Out:
# 279903      89
# 279904      89
# 279905      89
# 279906      89
# 279907      98
#           ...
# 5234958    159
# 5234959     99
# 5234960     80
# 5234961     62
# 5234962     62
# Name: price, Length: 3079773, dtype: int64

# %% [raw]
# merged_data.describe()
